# %% [markdown]
# # UPDATE Documents and Collections

# %%
from connect import db
from pymongo import UpdateOne

modificar = db.libros

# Actualizar stock de un libro
res = modificar.update_one(
    {'Titulo': 'La ciudad Verde'},
    {'$inc':
        {'Stock': 10}
    }
)

for doc in modificar.find({'Titulo':'La ciudad Verde'}):
    print(doc)


print('Cambios', res.matched_count, 'Total', res.modified_count)
# Out:
# Conexión exitosa a Atlas
# Conectado MongoDB Atlas: Base de datos biblioteca25
# Colecciones ['libros']
# {'_id': ObjectId('690e1defd2c56bfcab6f3b74'), 'Titulo': 'La ciudad Verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Literatura Peruana'], 'Stock': 24, 'Disponible': True}
# Cambios 1 Total 1

# %%
for doc in modificar.find({'Titulo':'La ciudad Verde'}):
    print(doc['Titulo'], 'hay', doc['Stock'], 'libros')
# Out:
# La ciudad Verde hay 24 libros

# %%
# Actualizar varios documentos
res2 = modificar.update_many(
    {},
    {'$set':{
        'disponible': True
        }
    }
)

print('Cambios', res2.matched_count, 'Total', res2.modified_count)
# Out:
# Cambios 24 Total 24

# %%
for doc in modificar.find({'disponible':True}):
    print('Disponible', doc['disponible'])
# Out:
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True

# %%
# Bulk write
operations = [
    UpdateOne(
        {'Titulo':'La ciudad Verde'},
        {'$set': {'Stock': 6}},
    )
]

modificar.bulk_write(operations)
# Out:
# BulkWriteResult({'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 1, 'nModified': 1, 'nRemoved': 0, 'upserted': []}, acknowledged=True)

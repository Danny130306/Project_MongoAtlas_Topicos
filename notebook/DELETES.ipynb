# %% [markdown]
# # Eliminando Archivos

# %%
from connect import db
eliminar = db.libros

# Delete 1
res = eliminar.delete_one({'Titulo':'1984'})
print(f'Se eliminaron {res.deleted_count} documentos.')
# Out:
# Conexión exitosa a Atlas
# Conectado MongoDB Atlas: Base de datos biblioteca25
# Colecciones ['libros']
# Se eliminaron 0 documentos.
